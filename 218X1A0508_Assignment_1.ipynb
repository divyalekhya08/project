# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv('/content/CarPrice_Assignment.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# # Check dataset size and info

# %%
# checking the dataset size
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# # Null  values checking and treatment

# %%
df.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# # Descriptive statistics

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.head(3)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
#
#    highwaympg    price
# 0          27  13495.0
# ...

# %%
df=df.drop(columns = 'car_ID',axis=1)
df.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %% [markdown]
# # Outlier checking and treatment

# %%
sns.boxplot(df.carbody)
# Out:
# <Axes: ylabel='carbody'>

# %%
sns.displot(df.carbody)

# %% [markdown]
# ## Outlier treatment - Replacing outliers with upperlimit

# %%
#upper_limit=Q3+1.5*IQR
#lower_limit=Q1-1.5*IQR
df.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
Q3 = df.horsepower.quantile(0.75)
Q1 = df.horsepower.quantile(0.25)

# %%
Q3
# Out:
# 116.0

# %%
Q1
# Out:
# 70.0

# %%
IQR = Q3 - Q1
IQR
# Out:
# 46.0

# %%
upper_limit = Q3 + 1.5 * IQR
upper_limit
# Out:
# 185.0

# %%
df['horsepower']=np.where(df['horsepower']>upper_limit,185,df['horsepower'])

# %%
sns.boxplot(df.horsepower)
# Out:
# <Axes: ylabel='horsepower'>

# %% [markdown]
# # Visualizations

# %% [markdown]
# # 1.Univariate Analysis

# %%
plt.pie(df['doornumber'].value_counts(),[0,0.1],labels = ['NO','Yes'],autopct = '%1.1f%%',colors = ['purple','yellow'],shadow = True)
plt.show()

# %%
plt.pie(df['carbody'].value_counts(), [0,0,0,0,0], labels= ['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'], autopct = '%1.1f%%', shadow = True,colors = ['green','orange','red','purple','pink'])
plt.title('carbody')
plt.show()

# %%
from matplotlib import rcParams
rcParams['figure.figsize']=8,8

# %%
sns.barplot(x =df['fueltype'].value_counts().index, y =df['fueltype'].value_counts(),palette ='husl')
# Out:
# <ipython-input-37-8654238acde5>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x =df['fueltype'].value_counts().index, y =df['fueltype'].value_counts(),palette ='husl')
# <Axes: xlabel='fueltype', ylabel='count'>

# %%
sns.barplot(x=df['carbody'].value_counts().index,y=df['carbody'].value_counts(),palette='Spectral')
# Out:
# <ipython-input-41-6e558d9a70b9>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['carbody'].value_counts().index,y=df['carbody'].value_counts(),palette='Spectral')
# <Axes: xlabel='carbody', ylabel='count'>

# %% [markdown]
# # 2.Bivariate Analysis

# %%
sns.violinplot(x = df['fueltype'],y = df['doornumber'], palette = 'Set1', data =df)
# Out:
# <ipython-input-42-4b0878b982d7>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = df['fueltype'],y = df['doornumber'], palette = 'Set1', data =df)
# <Axes: xlabel='fueltype', ylabel='doornumber'>

# %%
sns.catplot(x='aspiration', y = 'symboling',kind = 'box', data=df, palette='flare')
# Out:
# <ipython-input-43-6b94b33c3714>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='aspiration', y = 'symboling',kind = 'box', data=df, palette='flare')

# %%
sns.jointplot(x='carbody',y='symboling',data=df)

# %%
sns.lineplot(x=df.carbody,y=df.horsepower)
# Out:
# <Axes: xlabel='carbody', ylabel='horsepower'>

# %% [markdown]
# # 3.Multivariate Analysis

# %%
sns.pairplot(df)

# %% [markdown]
# # Transformations(Encoding)

# %%
# Transformation (Encoding)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['CarName'] = le.fit_transform(df['CarName'])
df['fueltype'] = le.fit_transform(df['fueltype'])
df['aspiration'] = le.fit_transform(df['aspiration'])
df['doornumber'] = le.fit_transform(df['doornumber'])
df['carbody'] = le.fit_transform(df['carbody'])
df['drivewheel'] = le.fit_transform(df['drivewheel'])
df['enginelocation'] = le.fit_transform(df['enginelocation'])
df['enginetype'] = le.fit_transform(df['enginetype'])
df['cylindernumber'] = le.fit_transform(df['cylindernumber'])
df['fuelsystem'] = le.fit_transform(df['fuelsystem'])
df
# Out:
#      symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0            3        2         1           0           1        0
# 1            3        3         1           0           1        0
# 2            1        1         1           0           1        2
# 3            2        4         1           0           0        3
# 4            2        5         1           0           0        3
# ..         ...      ...       ...         ...         ...      ...
# 200         -1      139         1           0           0        3
# 201         -1      138         1           1           0        3
# 202         -1      140         1           0           0        3
# 203         -1      142         0           1           0        3
# 204         -1      143         1           1           0        3
#
#      drivewheel  enginelocation  wheelbase  carlength  ...  enginesize  \
# 0             2               0       88.6      168.8  ...         130
# ...

# %%
df.corr()
# Out:
#                   symboling   CarName  fueltype  aspiration  doornumber  \
# symboling          1.000000 -0.107095  0.194311   -0.059866    0.664073
# CarName           -0.107095  1.000000 -0.069435    0.019914   -0.171745
# fueltype           0.194311 -0.069435  1.000000   -0.401397    0.191491
# aspiration        -0.059866  0.019914 -0.401397    1.000000   -0.031792
# doornumber         0.664073 -0.171745  0.191491   -0.031792    1.000000
# carbody           -0.596135  0.099691 -0.147853    0.063028   -0.680358
# drivewheel        -0.041671 -0.016129 -0.132257    0.066465    0.098954
# enginelocation     0.212471  0.055968  0.040070   -0.057191    0.137757
# wheelbase         -0.531954  0.014550 -0.308346    0.257611   -0.447357
# carlength         -0.357612  0.053016 -0.212679    0.234539   -0.398568
# carwidth          -0.232919 -0.075349 -0.233880    0.300567   -0.207168
# carheight         -0.541038  0.201900 -0.284631    0.087311   -0.552208
# ...

# %%
plt.figure(figsize =(18,13))
sns.heatmap(df.corr(), annot =True)
# Out:
# <Axes: >

# %%
numeric_columns = ['enginelocation','boreratio','price']
coorelation_matrix = df[numeric_columns].corr()

# %%
coorelation_matrix
# Out:
#                 enginelocation  boreratio     price
# enginelocation        1.000000   0.185042  0.324973
# boreratio             0.185042   1.000000  0.553173
# price                 0.324973   0.553173  1.000000

# %% [markdown]
# # X and Y Split

# %%
X=df.loc[:,['symboling','fueltype','doornumber','enginelocation','enginetype','cylindernumber','fuelsystem','horsepower','peakrpm','highwaympg']]
X.head()
# Out:
#    symboling  fueltype  doornumber  enginelocation  enginetype  \
# 0          3         1           1               0           0
# 1          3         1           1               0           0
# 2          1         1           1               0           5
# 3          2         1           0               0           3
# 4          2         1           0               0           3
#
#    cylindernumber  fuelsystem  horsepower  peakrpm  highwaympg
# 0               2           5         111     5000          27
# 1               2           5         111     5000          27
# 2               3           5         154     5000          26
# 3               2           5         102     5500          30
# 4               1           5         115     5500          22

# %%
y=df['price']

# %%
y.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()

# %%
scaled_x = pd.DataFrame(scale.fit_transform(X),columns = X.columns)
scaled_x.head()
# Out:
#    symboling  fueltype  doornumber  enginelocation  enginetype  \
# 0        1.0       1.0         1.0             0.0    0.000000
# 1        1.0       1.0         1.0             0.0    0.000000
# 2        0.6       1.0         1.0             0.0    0.833333
# 3        0.8       1.0         0.0             0.0    0.500000
# 4        0.8       1.0         0.0             0.0    0.500000
#
#    cylindernumber  fuelsystem  horsepower   peakrpm  highwaympg
# 0        0.333333    0.714286    0.459854  0.346939    0.289474
# 1        0.333333    0.714286    0.459854  0.346939    0.289474
# 2        0.500000    0.714286    0.773723  0.346939    0.263158
# 3        0.333333    0.714286    0.394161  0.551020    0.368421
# 4        0.166667    0.714286    0.489051  0.551020    0.157895

# %% [markdown]
# # Perform Train Test Split

# %%
# Perform Train Test Split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(scaled_x,y,test_size =0.2,random_state = 0)

# %%
x_train.head()
# Out:
#      symboling  fueltype  doornumber  enginelocation  enginetype  \
# 4          0.8       1.0         0.0             0.0    0.500000
# 71         0.2       1.0         0.0             0.0    0.833333
# 134        1.0       1.0         1.0             0.0    0.500000
# 145        0.4       1.0         0.0             0.0    0.666667
# 122        0.6       1.0         0.0             0.0    0.500000
#
#      cylindernumber  fuelsystem  horsepower   peakrpm  highwaympg
# 4          0.166667    0.714286    0.489051  0.551020    0.157895
# 71         0.000000    0.714286    0.781022  0.244898    0.052632
# 134        0.333333    0.714286    0.452555  0.448980    0.315789
# 145        0.333333    0.714286    0.459854  0.265306    0.342105
# 122        0.333333    0.142857    0.145985  0.551020    0.578947

# %%
x_train.shape
# Out:
# (164, 10)

# %%
x_test.shape
# Out:
# (41, 10)

# %% [markdown]
# # Train the data with suitable ML model

# %%
from sklearn.linear_model import LinearRegression
lr =LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([ 5548.29284014, 20735.47856106, 13963.63284743, -3707.54103921,
#        10630.83809647, 13405.1657855 ,  4138.03979605,  7491.37676421,
#        20634.14442391,  7342.61457778, 14625.0337471 , 25227.34764854,
#        10174.77833013, 12781.20761399,  5187.81047574, 13405.1657855 ,
#         9943.45607786, 15033.84456785,  9478.70208268,  5777.76011063,
#        12125.96082574, 12520.14967906,  8770.00261179, 13405.1657855 ,
#        20137.40180543,  6422.88163508,  7400.37399705, 12520.14967906,
#         8205.56145101,  5772.33116069,  7032.40780274,  9229.25292158,
#        17626.60320094, 10457.53737029,  6739.30113547, 24619.90827395,
#         8802.09342654, 20000.41741875,  5046.46899567, 30283.4934167 ,
#         4117.59875531])

# %% [markdown]
# # Test the model

# %%
x_test
# Out:
#      symboling  fueltype  doornumber  enginelocation  enginetype  \
# 52         0.6       1.0         1.0             0.0    0.500000
# 181        0.2       1.0         0.0             0.0    0.000000
# 5          0.8       1.0         1.0             0.0    0.500000
# 18         0.8       1.0         1.0             0.0    0.333333
# 188        0.8       1.0         0.0             0.0    0.500000
# 170        0.8       1.0         1.0             0.0    0.500000
# 76         0.8       1.0         1.0             0.0    0.500000
# 154        0.4       1.0         0.0             0.0    0.500000
# 104        1.0       1.0         1.0             0.0    0.833333
# 33         0.6       1.0         1.0             0.0    0.500000
# 12         0.4       1.0         1.0             0.0    0.500000
# 129        0.6       1.0         1.0             0.0    0.166667
# 55         1.0       1.0         1.0             0.0    1.000000
# ...

# %%
y_test
# Out:
# 52      6795.0
# 181    15750.0
# 5      15250.0
# 18      5151.0
# 188     9995.0
# 170    11199.0
# 76      5389.0
# 154     7898.0
# 104    17199.0
# 33      6529.0
# 12     20970.0
# 129    31400.5
# 55     10945.0
# 66     18344.0
# 45      8916.5
# 169     9989.0
# 130     9295.0
# 7      18920.0
# 37      7895.0
# 152     6488.0
# 80      9959.0
# 111    15580.0
# 131     9895.0
# 171    11549.0
# 179    15998.0
# 138     5118.0
# 156     6938.0
# 113    16695.0
# 161     8358.0
# 89      5499.0
# 183     7975.0
# 193    12290.0
# 125    22018.0
# 173     8948.0
# 92      6849.0
# 16     41315.0
# 189    11595.0
# 136    18150.0
# 22      6377.0
# 74     45400.0
# 44      8916.5
# Name: price, dtype: float64

# %% [markdown]
# # Test with random values

# %%
random_values = np.array([[0.6,0.7,0.5,0.8,0.9,0.3,0.5,0.2,0.8,0.4]])
lr.predict(random_values)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([17812.21042501])

# %%
from sklearn import metrics

# %% [markdown]
# # Evaluating the model

# %%
# R-Square
metrics.r2_score(y_test,y_pred)
# Out:
# 0.7131591518941645

# %%
# MSE
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 22206173.849717915

# %%
# RMSE

np.sqrt(metrics.mean_squared_error(y_test,y_pred))
# Out:
# 4712.342713525611
